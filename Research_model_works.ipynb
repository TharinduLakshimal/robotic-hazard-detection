# %% [markdown]
# <a href="https://colab.research.google.com/github/TharinduLakshimal/robotic-hazard-detection/blob/version-1/Research_model_works.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.0 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.1/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uwXX0JgH0syUfCz3yEa1")
project = rf.workspace("tharindus-workspace-b7nsk").project("broken-glass-detection")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Broken-Glass-detection-1 in yolov8:: 100%|██████████| 182/182 [00:00<00:00, 5627.12it/s]

# %%
print(dataset.location)
# Out:
# /content/Broken-Glass-detection-1

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#   Using cached ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# ...
# Using cached ultralytics-8.4.41-py3-none-any.whl (1.2 MB)
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.103
#     Uninstalling ultralytics-8.2.103:
#       Successfully uninstalled ultralytics-8.2.103
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uwXX0JgH0syUfCz3yEa1")
project = rf.workspace("tharindus-workspace-b7nsk").project("broken-glass-detection")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
print(dataset.location)
# Out:
# /content/Broken-Glass-detection-1

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon 2.20GHz)
# ...

# %%
import os
print(os.listdir(dataset.location))
# Out:
# ['data.yaml', 'README.roboflow.txt', 'train']

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uwXX0JgH0syUfCz3yEa1")
project = rf.workspace("tharindus-workspace-b7nsk").project("broken-glass-detection")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Broken-Glass-detection-2 in yolov8:: 100%|██████████| 130/130 [00:00<00:00, 5760.25it/s]

# %%
print(dataset.location)
# Out:
# /content/Broken-Glass-detection-2

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon 2.20GHz)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-710802f5-0fc2-40fc-9919-a6dabaf2254c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-710802f5-0fc2-40fc-9919-a6dabaf2254c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train-2/weights/best.pt")

model.predict(source="/content/test.jpeg", show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/test.jpeg: 640x480 (no detections), 196.1ms
# Speed: 19.3ms preprocess, 196.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'clean', 1: 'dust'}
#  obb: None
#  orig_img: array([[[ 72,  68,  63],
#          [ 91,  87,  82],
#          [106, 103,  98],
#          ...,
#          [198, 220, 245],
#          [198, 220, 245],
#          [197, 219, 244]],
#
#         [[ 74,  70,  65],
#          [ 92,  88,  83],
#          [108, 105, 100],
#          ...,
#          [199, 221, 246],
#          [198, 220, 245],
#          [198, 220, 245]],
#
#         [[ 75,  71,  66],
#          [ 93,  89,  84],
#          [109, 106, 101],
#          ...,
#          [200, 222, 247],
#          [199, 221, 246],
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train-2/weights/best.pt")

model.predict(source="/content/test2.jpeg", show=True)
# Out:
# image 1/1 /content/test2.jpeg: 640x480 1 dust, 172.8ms
# Speed: 3.4ms preprocess, 172.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'clean', 1: 'dust'}
#  obb: None
#  orig_img: array([[[188, 199, 203],
#          [188, 199, 203],
#          [188, 199, 203],
#          ...,
#          [184, 213, 255],
#          [184, 213, 255],
#          [184, 213, 255]],
#
#         [[189, 200, 204],
#          [189, 200, 204],
#          [189, 200, 204],
#          ...,
#          [184, 213, 255],
#          [184, 213, 255],
#          [184, 213, 255]],
#
#         [[189, 200, 204],
#          [189, 200, 204],
#          [189, 200, 204],
#          ...,
#          [184, 213, 255],
#          [184, 213, 255],
#          [184, 213, 255]],
#
#         ...,
#
#         [[120, 134, 133],
#          [120, 134, 133],
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train-2/weights/best.pt")

model.predict(source="/content/test3.jpeg", show=True)
# Out:
# image 1/1 /content/test3.jpeg: 640x480 (no detections), 166.3ms
# Speed: 3.4ms preprocess, 166.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'clean', 1: 'dust'}
#  obb: None
#  orig_img: array([[[153, 167, 166],
#          [156, 170, 169],
#          [160, 174, 173],
#          ...,
#          [137,  88,  42],
#          [145,  92,  42],
#          [141,  87,  34]],
#
#         [[156, 170, 169],
#          [158, 172, 171],
#          [161, 175, 174],
#          ...,
#          [143,  94,  50],
#          [152,  99,  49],
#          [145,  91,  38]],
#
#         [[159, 173, 172],
#          [160, 174, 173],
#          [162, 176, 175],
#          ...,
#          [148,  97,  54],
#          [155, 101,  54],
#          [144,  89,  38]],
#
#         ...,
#
#         [[ 60,  82,  93],
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train-2/weights/best.pt")

model.predict(source="/content/test4.jpeg", show=True)
# Out:
# image 1/1 /content/test4.jpeg: 640x480 2 cleans, 168.8ms
# Speed: 4.1ms preprocess, 168.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'clean', 1: 'dust'}
#  obb: None
#  orig_img: array([[[198, 211, 219],
#          [196, 209, 217],
#          [195, 208, 216],
#          ...,
#          [234, 255, 254],
#          [234, 255, 254],
#          [234, 255, 254]],
#
#         [[197, 210, 218],
#          [196, 209, 217],
#          [194, 207, 215],
#          ...,
#          [234, 255, 254],
#          [234, 255, 254],
#          [234, 255, 254]],
#
#         [[197, 210, 218],
#          [195, 208, 216],
#          [194, 207, 215],
#          ...,
#          [234, 255, 254],
#          [234, 255, 254],
#          [234, 255, 254]],
#
#         ...,
#
#         [[ 45,  71,  85],
#          [ 46,  72,  86],
# ...
