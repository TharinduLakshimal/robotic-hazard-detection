# %% [markdown]
# <a href="https://colab.research.google.com/github/TharinduLakshimal/robotic-hazard-detection/blob/version-2/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat May 23 13:14:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 71.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 126.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uwXX0JgH0syUfCz3yEa1")
project = rf.workspace("tharindus-workspace-b7nsk").project("broken-glass-ys2m6")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Broken-Glass-1 in yolov8:: 100%|██████████| 567/567 [00:00<00:00, 4526.12it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# %%
# !ls
# Out:
# Broken-Glass-1	sample_data

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Broken-Glass-1/data.yaml",
    epochs=30,
    imgsz=640,
    batch=8
)
# Out:
# ...
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO("yolov8n.pt")

model.train(
    data="/content/Broken-Glass-1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    name="yolov8n_50e"
)
# Out:
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/runs/detect/yolov8n_50e
# Out:
# args.yaml			 labels.jpg	      train_batch1.jpg
# BoxF1_curve.png			 results.csv	      train_batch2.jpg
# BoxP_curve.png			 results.png	      val_batch0_labels.jpg
# BoxPR_curve.png			 train_batch0.jpg     val_batch0_pred.jpg
# BoxR_curve.png			 train_batch1240.jpg  val_batch1_labels.jpg
# confusion_matrix_normalized.png  train_batch1241.jpg  val_batch1_pred.jpg
# confusion_matrix.png		 train_batch1242.jpg  weights

# %%
# !ls /content/runs/detect/yolov8n_50e/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files

files.download('/content/runs/detect/yolov8n_50e/weights/best.pt')

# %%
files.download('/content/runs/detect/yolov8n_50e/results.png')

# %%
model = YOLO("yolov8n.pt")

model.train(
    data="/content/Broken-Glass-1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    name="yolov8n_100e"
)
# Out:
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/runs/detect/yolov8n_100e/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files

files.download('/content/runs/detect/yolov8n_100e/weights/best.pt')

# %%
files.download('/content/runs/detect/yolov8n_100e/results.png')

# %%
files.download('/content/runs/detect/yolov8n_100e/confusion_matrix.png')

# %%
files.download('/content/runs/detect/yolov8n_50e/confusion_matrix.png')

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

model.train(
    data="/content/Broken-Glass-1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    name="yolo11n_50e"
)
# Out:
# ...
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/runs/detect/yolo11n_50e/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files

files.download('/content/runs/detect/yolo11n_50e/weights/best.pt')

# %%
files.download('/content/runs/detect/yolo11n_50e/results.png')

# %%
files.download('/content/runs/detect/yolo11n_50e/confusion_matrix.png')

# %%
model = YOLO("yolo11n.pt")

model.train(
    data="/content/Broken-Glass-1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    name="yolo11n_100e"
)
# Out:
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files

files.download('/content/runs/detect/yolo11n_100e/weights/best.pt')

# %%
files.download('/content/runs/detect/yolo11n_100e/results.png')

# %%
files.download('/content/runs/detect/yolo11n_100e/confusion_matrix.png')
